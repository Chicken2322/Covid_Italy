# %% [markdown]
# <a href="https://colab.research.google.com/github/Chicken2322/Covid_Italy/blob/master/covid_italy_CT_Scan_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Load and compile the model.

import tensorflow as tf 
model = tf.keras.models.load_model('/content/drive/MyDrive/Covid_Italy_CTSCAN_25/Covid_model_CTSCAN_25.h5')
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
#Importing the necessary files

from keras.preprocessing import image
from keras.models import load_model
from keras.applications.vgg16 import preprocess_input
import matplotlib.pyplot as plt
import numpy as np

# %%
#Testing the model with a new data

img = image.load_img('/content/drive/MyDrive/Covid_Italy_CTSCAN_25/keras-covid-19/dataset/covid/auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg', target_size=(224, 224)) 
imgplot = plt.imshow(img)
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
img_data = preprocess_input(x)
classes = model.predict(img_data)
New_pred = np.argmax(classes, axis=1)
if New_pred==[1]:
  print('Prediction: Normal')
else:
  print('Prediction: Corona')
# Out:
# Prediction: Corona

# %%
img = image.load_img('/content/drive/MyDrive/Covid_Italy_CTSCAN_25/keras-covid-19/dataset/normal/NORMAL2-IM-0315-0001.jpeg', target_size=(224, 224)) 
x = image.img_to_array(img)
imgplot = plt.imshow(img)
x = np.expand_dims(x, axis=0)
img_data = preprocess_input(x)
classes = model.predict(img_data)
New_pred = np.argmax(classes, axis=1)
if New_pred==[1]:
  print('Prediction: Normal')
else:
  print('Prediction: Corona')
# Out:
# Prediction: Normal
